# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("happyscore_income.csv")

# %%
df
# Out:
#           country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 0         Armenia                   37.0               4.9              2.42
# 1          Angola                   26.0               4.3              3.19
# 2       Argentina                   60.0               7.1              1.91
# 3         Austria                   59.0               7.2              2.11
# 4       Australia                   65.0               7.6              1.80
# ..            ...                    ...               ...               ...
# 106       Uruguay                   58.0               7.0              2.13
# 107       Vietnam                   53.0               6.1              1.77
# 108  South Africa                   49.0               6.3              2.47
# 109        Zambia                   37.0               5.0              2.61
# 110      Zimbabwe                   33.0               4.1              2.16
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                111 non-null    object
#  1   adjusted_satisfaction  111 non-null    float64
#  2   avg_satisfaction       111 non-null    float64
#  3   std_satisfaction       111 non-null    float64
#  4   avg_income             111 non-null    float64
#  5   median_income          111 non-null    float64
#  6   income_inequality      111 non-null    float64
#  7   region                 111 non-null    object
#  8   happyScore             111 non-null    float64
#  9   GDP                    111 non-null    float64
#  10  country.1              111 non-null    object
# dtypes: float64(8), object(3)
# memory usage: 9.7+ KB

# %%
df["region"].value_counts()
# Out:
# 'Sub-Saharan Africa'                 30
# 'Central and Eastern Europe'         23
# 'Western Europe'                     19
# 'Latin America and Caribbean'        16
# 'Southeastern Asia'                   7
# 'Middle East and Northern Africa'     5
# 'Southern Asia'                       5
# 'Eastern Asia'                        3
# 'North America'                       2
# 'Australia and New Zealand'           1
# Name: region, dtype: int64

# %%
df["happyScore"].value_counts()
# Out:
# 6.983    1
# 4.694    1
# 7.119    1
# 4.739    1
# 6.329    1
#         ..
# 4.571    1
# 5.948    1
# 7.200    1
# 5.791    1
# 6.750    1
# Name: happyScore, Length: 111, dtype: int64

# %%
df.groupby(by="region").mean()
# Out:
#                                    adjusted_satisfaction  avg_satisfaction  \
# region
# 'Australia and New Zealand'                    65.000000          7.600000
# 'Central and Eastern Europe'                   46.000000          5.717391
# 'Eastern Asia'                                 48.666667          6.100000
# 'Latin America and Caribbean'                  59.062500          7.187500
# 'Middle East and Northern Africa'              47.800000          5.980000
# 'North America'                                65.500000          7.650000
# 'Southeastern Asia'                            52.142857          6.242857
# 'Southern Asia'                                44.600000          5.440000
# 'Sub-Saharan Africa'                           34.833333          4.380000
# 'Western Europe'                               62.736842          7.321053
#
#                                    std_satisfaction    avg_income  \
# region
# ...

# %%
df2 = df.groupby(by="region").mean()

# %%
df2
# Out:
#                                    adjusted_satisfaction  avg_satisfaction  \
# region
# 'Australia and New Zealand'                    65.000000          7.600000
# 'Central and Eastern Europe'                   46.000000          5.717391
# 'Eastern Asia'                                 48.666667          6.100000
# 'Latin America and Caribbean'                  59.062500          7.187500
# 'Middle East and Northern Africa'              47.800000          5.980000
# 'North America'                                65.500000          7.650000
# 'Southeastern Asia'                            52.142857          6.242857
# 'Southern Asia'                                44.600000          5.440000
# 'Sub-Saharan Africa'                           34.833333          4.380000
# 'Western Europe'                               62.736842          7.321053
#
#                                    std_satisfaction    avg_income  \
# region
# ...

# %%
plt.figure(figsize=(30,20))
sns.barplot(x=df2.index, y=df2.happyScore, data=df2)
plt.title("Mean Happy Score by Region", size=20)
plt.xlabel("Region", size=20)
plt.ylabel("Mean Happy Score", size=20)

plt.show()
