# %% [markdown]
# ### Write a program that prints out a greeting which includes your name and where you are from.

# %%
print("I am Dennis from Malaysia")
# Out:
# I am Dennis from Malaysia
